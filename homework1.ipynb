# %%
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_excel('hw#1_data.xlsx')

# %%
# Histogram X2, display with space between bars
plt.hist(dataset['X2'], bins=4, label='X2',rwidth=0.99)
# Out:
# (array([3., 1., 2., 2.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(dataset['X3'], bins=3, label='X3', rwidth=0.99)
# Out:
# (array([1., 3., 4.]),
#  array([2.8       , 3.16666667, 3.53333333, 3.9       ]),
#  <BarContainer object of 3 artists>)

# %%
# Box plot for X3
plt.boxplot(dataset['X3'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2321c947f50>,
#   <matplotlib.lines.Line2D at 0x2321c946d50>],
#  'caps': [<matplotlib.lines.Line2D at 0x2321c97f690>,
#   <matplotlib.lines.Line2D at 0x2321c97e810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2321c947190>],
#  'medians': [<matplotlib.lines.Line2D at 0x2321c97c7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2321c97f2d0>],
#  'means': []}

# %%
# Scatterplot X3 and X4
plt.scatter(dataset['X3'], dataset['X4'], label='X3 and X4')
